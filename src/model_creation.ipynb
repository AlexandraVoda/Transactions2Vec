# %% [markdown]
# ### Introduction
# I'll build a recommender system using a modified version of Word2Vec, named Item2Vec ([1]), which consists in a collaborative filtering algorithm that aplies Word2Vec's Skip-Gram architecture on a non-natural language dataset.
#
# Word2Vec is a 1 hidden layer fully connected neural network that learns vector embeddings of words in a latent space. These embeddings are able to preserve word semantincs based on the their context (defined by a window size). Words that appear in similar contexts will tend to have similar vector representations.
# Word2Vec comes with 2 architecture options:
# 1. Continuous bag of words (CBOW): tries to predict a word based on its context.
# 2. Skip Gram (SG): tries to predict the context of a word that is given as an input.
#
# Since Item2Vec uses Skip-Gram, I'll only focus on its presentation.
#
# The image below ([4]) shows the neural network architecture.
# ![skip_gram_image_placeholder](./../images/skip_gram_net_arch.png)
#
# The input layer has the size of the vocabulary (10000 in the example above) and receives the one-hot vector representation of the word used for prediction.
#
# The hidden layer size is equal to the dimension of learnt vector embeddings (300 in the example above) and represents a hyperparameter. The weight matrix will have 300 columns (the number of features) and 10000 rows (one for word in the vocabulary).
#
# The output layer gives a probability distribution that will tell for each word in the vocabulary the probability of it being part of the input word's context.
#
# There are some additional techniques that the authors of Word2Vec proposed in their second paper ([5]) in order to optimize the training of the neural network.
#
# **Subsampling**\
# It is used to decrease the number of training examples by removing the words that appear most frequently. Usually, these are stop words that do not have relevant semantic meaning, since they appear in all sorts of contexts. The probability of a word being removed is given by the following formula
#
# ![subsampling_image_placeholder](./../images/subsampling.png)
#
# where f(w) represents the frequency of the given word in the vocabulary and t is a hyperparameter threshold usually chosen around 10<sup>-5</sup>.
#
# **Negative sampling**
# The training of this network will require a lot of time, since it implies the updating of the weight matrix which for a vocabulary of 10000 words and a hidden layer of 300 neurons will have **3 millions** weights. That's why a new technique called negative sampling has been introduced. This optimization implies modifing a very small sample of weights:
# - the weight of the correct output neuron, so that it will result in a high probability of being part of the input word's context
# - select a few (5-20) words from the vocabulary that will be treated as negative examples; Their weight will be updated so that their probability of being part of the input word's context will be decreased; For small vocabularies 5-20 negative samples are needed, whereas for larger vocabularies 2-5 samples are sufficient.
# The probability of a word being picked as a negative example is given by the following formula
#
# ![negative_sampling_image_placeholder](./../images/negative_sampling.png)
#
# where f(w) represents the frequency of the given word in the vocabulary. Therefore, most frequent words will have a higher probabily of being picked as negative examples.
#
#
# **Item2Vec** aims to apply Word2Vec's Skip-Gram with negative sampling architecture on various sequences of objects belonging to non-linguistic datasets. Item2Vec can be applied to shopping cart items, movie reviews lists, lists of appreciated songs etc. in order to build a recommender system that is based on calculating the similarities of items that the user enjoys. Another characteristic of Item2Vec is that the window size is considered infinite because all the items in a given sequence of objects are considered to be part of the same context.
#
# In this script I'll train this model on an online transactions dataset that contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail that sells unique all-occasion gifts ([6]).
#
# The data has been explored and cleaned in separate scripts of this project. Check `data/initial_exploration` notebook and `data/make_dataset.py`.

# %%
import pandas as pd;
import numpy as np;
import logging

from random import shuffle
from sklearn.model_selection import KFold
from gensim.models import Word2Vec
logging.basicConfig(level=logging.INFO)

# %% [markdown]
# By grouping the purchased items based on their **InvoiceNo** we'll get a list of transactions. Each transaction will consist in a list of **StockCodes**.
#
# We'll train a **Word2Vec** model that will try to learn the embeddings of the StockCodes in a latent space. Basically, we treat the purchased items (their *Stockcodes*) as "words" and the whole transaction (the sequence of items purchased together) as a "sentence". We can consider that items which are bought together are similar and belong to the same context.

# %% [markdown]
# Word2Vec hyperparameters were picked taking into account various values used in literature and based on personal experiments.
#
# | Parameter name | Description | Value | Comments on the chosen values |
# | --- | ----------- | ------- | ----- |
# | size | Size of hidden layer (dimension of learned vectors) | 32 | Worked well for this use case. Multiple of 4 is chosen for greater performance (according to gensim documentation). |
# | window | The size of window defining the context of the word | 999 | A big value, so all the products in a given transaction define the context used in learning |
# | min_count | Minimum number of appearances for a word to be kept in the vocabulary | 4 | A product should appear at least 4 times in the whole corpus in order to be kept in the vocabulary |
# | iter | Number of epochs | 30 | Tried: [10, 15, 20, 25, **30**, 35]. Highest score reached at 30 |
# | sg | 1 for Skip-Gram strategy, 0 for CBOW | 1 | Skip-Gram technique works best for Item2Vec. According to Mikolov, Skip-Gram is a good solution for small datasets and is able to create a good represenation for rare words.|
# | hs | 1 for hierarchical softmax, 0 and and negative > 0 for use of negative sampling | 0 | Chose 0 because applying negative-sampling gives better results |
# | sample | a threshold used for configuring the number of most popular words that are removed from the vocabulary | 5e-4 | Tried [e-4, **5e-4**, e-5].  |
# | negative | how many random words are marked as negative examples | 30 | Tried: [5, 10, 20, **30**, 35]. Because the dataset is small, a higher value was needed.  |
#
# After training the model, I evaluate it the following manner:\
# For each transaction in the test set:
# 1. Extract the last item in the transaction. The model will try to predict this item based on the other items found in the transaction. If the extracted code is not part of the model's vocabulary, I'll keep extracting codes until the condition is met. I do so because the model will be unable to predict a 'word' that is not part of its vocabulary
# 2. Remove all the objects from the transaction that are not found in the vocabulary.
# 3. If the transaction is left empty after the first 2 steps, remove it from the test set.
# 4. Predict most similar K items to the ones from the transaction resulted on step 2. If the product extracted during the first step appears in the list of predictions, I'll increase the hit score.
#
# The final score will be equal to the ratio between the total number of hits and the test set size. Three values have been considered for K: 10, 15, 20. Obviously, better scores are achived when K is larger.
#
# 5-Folds Cross-validation has been used to compute the mean score of the model. The following scores have been obtained:
# - for K = 10: 9.57%
# - for K = 15: 11.91%
# - for K = 20: 13.72%

# %%
class Transactions2Vec:
    def __init__(self):
        self.data = pd.read_csv('./data/data.csv', header=0)

        # Group entries by InvoiceNO 
        entryByInvoiceNo = self.data.groupby(["InvoiceNo"])
        # For each group extract the list of StockCodes and store them separately
        # These lists of StockCodes will be the "sentences" used in training the Word2Vec model
        self.transactions = [entryByInvoiceNo.get_group(gp)['StockCode'].tolist() for gp in entryByInvoiceNo.groups]

            
    def create_and_evaluate(self):
        self.scores = [[],[],[]]
        self.k_values = [10, 15, 20]
        
        # Use 5-Fold Cross-validation for model evaluation
        kf = KFold(n_splits=5, shuffle=True)
        iter = 1
        for train, test in kf.split(self.transactions):
            self.train_data = [self.transactions[x] for x in train]
            self.test_data = [self.transactions[x] for x in test]
            self.create_model(iter)
            self.evaluate_model()
            iter+=1

        # After getting a score for each of the 5 models, average them to get a mean score
        for i in range(len(self.k_values)):
            print("Mean score @{}= {}".format(self.k_values[i], np.mean(self.scores[i])))

    def create_model(self, iter):
        self.model = Word2Vec(self.train_data,
                              size=32,
                              window=999,
                              min_count=4,
                              workers=8,
                              iter=30,
                              sg=1,
                              hs=0,
                              sample=5e-4,
                              negative=30)
        
        # Save the model for each try
        model_name = "model_" + str(iter)
        self.model.save(model_name)

    def evaluate_model(self):
        test_size = float(len(self.test_data))
        hits = [0.0, 0.0, 0.0]
        
        for transaction in self.test_data:
            # If the transaction only contains a product, we skip it
            if len(transaction) < 2: 
                test_size -= 1.0
                continue
                
            # Extract the last bought item
            last_bought_product = transaction.pop() 
            # If the item is not found in the model's vocabulary, keep extracting other products
            while len(transaction) > 0 and last_bought_product not in self.model.wv.vocab:       
                last_bought_product = transaction.pop()
            # Create a list of all the remaining transaction's products that are part of the model's vocabulary
            products = [product for product in transaction if product in self.model.wv.vocab] 
            
            # If the list only contains a product, we skip this transaction
            if len(products) < 2:
                test_size -= 1.0
                continue
                
            # Predict top K products most similar to the ones extracted in the list above and check if the last_bought_item appears in the list of predictions
            for i in range(len(self.k_values)):
                prediction = self.model.wv.most_similar_cosmul(positive=products, topn=self.k_values[i])
                for predicted_product, score in prediction:
                    if predicted_product == last_bought_product:
                        hits[i] += 1.0

        # For each K value, compute the ratio between the number of correct predictions and the total test size.
        for i in range(len(hits)):
            score = hits[i] / test_size
            self.scores[i].append(score)
            print("Score @{}: {}".format(self.k_values[i], score))

# %%
model = Transactions2Vec()
model.create_and_evaluate()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:3249: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# INFO:gensim.models.word2vec:collecting all words and their counts
# INFO:gensim.models.word2vec:PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #10000, processed 241132 words, keeping 3677 word types
# INFO:gensim.models.word2vec:collected 3901 word types from a corpus of 425288 raw words and 16582 sentences
# INFO:gensim.models.word2vec:Loading a fresh vocabulary
# INFO:gensim.models.word2vec:effective_min_count=4 retains 3485 unique words (89% of original 3901, drops 416)
# INFO:gensim.models.word2vec:effective_min_count=4 leaves 424520 word corpus (99% of original 425288, drops 768)
# INFO:gensim.models.word2vec:deleting the raw counts dictionary of 3901 items
# INFO:gensim.models.word2vec:sample=0.0005 downsamples 100 most-common words
# INFO:gensim.models.word2vec:downsampling leaves estimated 406788 word corpus (95.8% of prior 424520)
# INFO:gensim.models.base_any2vec:estimated required memory for 3485 words and 32 dimensions: 2634660 bytes
# INFO:gensim.models.word2vec:resetting layer weights
# INFO:gensim.models.base_any2vec:training model with 8 workers on 3485 vocabulary and 32 features, using sg=1 hs=0 sample=0.0005 negative=30 window=999
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 2.51% examples, 2690 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 6.92% examples, 4960 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 9.48% examples, 5452 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 14.03% examples, 6982 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 22.90% examples, 9964 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 28.07% examples, 10793 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 31.09% examples, 10609 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 41.89% examples, 12728 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 49.99% examples, 12087 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 57.83% examples, 12992 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 62.39% examples, 13297 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 64.68% examples, 13077 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 66.89% examples, 12711 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 71.29% examples, 12981 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 77.86% examples, 13602 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 84.43% examples, 12721 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 86.57% examples, 11883 words/s, in_qsize 7, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 94.54% examples, 12475 words/s, in_qsize 3, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 96.65% examples, 12286 words/s, in_qsize 2, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 1 : training on 425288 raw words (406844 effective words) took 32.4s, 12575 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 2.51% examples, 2475 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 6.92% examples, 4587 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 9.48% examples, 5215 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 15.79% examples, 7288 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 25.27% examples, 9684 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 34.15% examples, 10945 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 41.89% examples, 12227 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 47.19% examples, 12298 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 49.90% examples, 11436 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 60.17% examples, 12771 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 62.39% examples, 12370 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 66.89% examples, 12668 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 71.26% examples, 12638 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 75.76% examples, 12869 words/s, in_qsize 12, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 80.11% examples, 13098 words/s, in_qsize 10, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 84.43% examples, 12198 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 86.57% examples, 11682 words/s, in_qsize 7, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 94.54% examples, 12100 words/s, in_qsize 3, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 98.54% examples, 12191 words/s, in_qsize 1, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 2 : training on 425288 raw words (406861 effective words) took 33.6s, 12121 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 2.51% examples, 2263 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 6.92% examples, 4881 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 9.48% examples, 4873 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 14.03% examples, 6462 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 25.27% examples, 10403 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 28.07% examples, 9686 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 36.75% examples, 10984 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 47.19% examples, 12874 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 49.99% examples, 11299 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 55.30% examples, 11617 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 62.46% examples, 12340 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 66.89% examples, 12340 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 69.11% examples, 12087 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 73.44% examples, 12239 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 84.43% examples, 11953 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 86.57% examples, 11511 words/s, in_qsize 7, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 94.54% examples, 11872 words/s, in_qsize 3, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 96.65% examples, 11757 words/s, in_qsize 2, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 100.00% examples, 11847 words/s, in_qsize 0, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 3 : training on 425288 raw words (406638 effective words) took 34.3s, 11847 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 2.51% examples, 2400 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 6.92% examples, 3837 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 16.28% examples, 7555 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 20.41% examples, 8664 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 25.49% examples, 9266 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 36.12% examples, 11325 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 41.89% examples, 11816 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 47.19% examples, 11877 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 49.99% examples, 11586 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 57.64% examples, 12334 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 62.46% examples, 12076 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 69.07% examples, 12322 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 75.76% examples, 12711 words/s, in_qsize 12, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 80.11% examples, 12788 words/s, in_qsize 10, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 84.43% examples, 12009 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 86.57% examples, 11617 words/s, in_qsize 7, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 92.71% examples, 12141 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 94.54% examples, 11808 words/s, in_qsize 3, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 96.42% examples, 11727 words/s, in_qsize 2, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 4 : training on 425288 raw words (406796 effective words) took 34.1s, 11941 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 2.51% examples, 2413 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 6.92% examples, 4517 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 9.48% examples, 5011 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 16.28% examples, 7467 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 22.99% examples, 9241 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 28.07% examples, 9840 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 36.75% examples, 11140 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 44.62% examples, 11911 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 49.99% examples, 11114 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 60.17% examples, 12522 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 64.68% examples, 12284 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 66.89% examples, 11940 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 73.44% examples, 12669 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 77.86% examples, 12842 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 84.43% examples, 11922 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 86.57% examples, 11395 words/s, in_qsize 7, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 94.54% examples, 11790 words/s, in_qsize 3, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 98.54% examples, 11985 words/s, in_qsize 1, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 5 : training on 425288 raw words (406568 effective words) took 34.0s, 11952 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 2.51% examples, 2090 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 6.92% examples, 4185 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 8.85% examples, 4713 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 18.04% examples, 8201 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 22.69% examples, 8879 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 28.07% examples, 9706 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 36.54% examples, 11065 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 44.46% examples, 11697 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 49.90% examples, 11375 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 57.64% examples, 12028 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 62.39% examples, 11855 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 66.89% examples, 12038 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 73.44% examples, 12618 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 77.86% examples, 12792 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 80.11% examples, 12585 words/s, in_qsize 10, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 84.43% examples, 12077 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 86.31% examples, 11270 words/s, in_qsize 7, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 94.54% examples, 11746 words/s, in_qsize 3, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 96.65% examples, 11560 words/s, in_qsize 2, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 6 : training on 425288 raw words (406861 effective words) took 34.4s, 11812 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 2.51% examples, 2400 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 6.92% examples, 4416 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 9.48% examples, 4644 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 18.65% examples, 7808 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 25.27% examples, 9353 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 33.73% examples, 10426 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 44.46% examples, 11704 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 49.99% examples, 11195 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 55.30% examples, 11431 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 60.17% examples, 11689 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 66.89% examples, 12134 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 71.29% examples, 12075 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 77.85% examples, 12319 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 84.43% examples, 11832 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 86.57% examples, 11305 words/s, in_qsize 7, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 92.71% examples, 11697 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 94.54% examples, 11424 words/s, in_qsize 3, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 100.00% examples, 11687 words/s, in_qsize 0, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 7 : training on 425288 raw words (406931 effective words) took 34.8s, 11686 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 2.51% examples, 2434 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 6.92% examples, 4506 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 9.48% examples, 4912 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 16.28% examples, 7483 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 20.41% examples, 8488 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 28.07% examples, 9669 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 36.75% examples, 10973 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 44.46% examples, 11743 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 49.99% examples, 11066 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 57.64% examples, 12017 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 62.39% examples, 12140 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 64.68% examples, 11966 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 69.11% examples, 11952 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 75.76% examples, 12341 words/s, in_qsize 12, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 82.20% examples, 12873 words/s, in_qsize 9, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 84.43% examples, 11583 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 86.57% examples, 11047 words/s, in_qsize 7, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 94.54% examples, 11573 words/s, in_qsize 3, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 98.54% examples, 11742 words/s, in_qsize 1, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 8 : training on 425288 raw words (406949 effective words) took 34.9s, 11653 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 2.51% examples, 2386 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 6.92% examples, 4583 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 9.48% examples, 4951 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 14.35% examples, 6453 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 18.65% examples, 7594 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 25.27% examples, 9408 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 31.12% examples, 9896 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 41.89% examples, 11562 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 47.19% examples, 11986 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 49.99% examples, 10902 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 57.64% examples, 11807 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 62.39% examples, 11974 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 66.89% examples, 11907 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 71.29% examples, 11980 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 77.86% examples, 12677 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 82.20% examples, 12910 words/s, in_qsize 9, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 84.43% examples, 11633 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 86.57% examples, 11139 words/s, in_qsize 7, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 92.71% examples, 11587 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 96.65% examples, 11630 words/s, in_qsize 2, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 100.00% examples, 11684 words/s, in_qsize 0, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 9 : training on 425288 raw words (406728 effective words) took 34.8s, 11683 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 2.51% examples, 2369 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 6.92% examples, 4377 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 9.48% examples, 4886 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 16.28% examples, 7111 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 22.99% examples, 8854 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 31.09% examples, 9811 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 41.89% examples, 11601 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 44.46% examples, 11412 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 49.90% examples, 10855 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 60.17% examples, 12037 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 62.39% examples, 11670 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 66.89% examples, 11991 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 69.11% examples, 11847 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 75.76% examples, 12360 words/s, in_qsize 12, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 79.95% examples, 12292 words/s, in_qsize 10, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 84.43% examples, 11596 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 86.57% examples, 11025 words/s, in_qsize 7, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 94.54% examples, 11450 words/s, in_qsize 3, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 96.65% examples, 11186 words/s, in_qsize 2, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 10 : training on 425288 raw words (406573 effective words) took 35.6s, 11418 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 2.51% examples, 2414 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 6.92% examples, 4585 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 9.48% examples, 4944 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 14.03% examples, 6556 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 18.85% examples, 7369 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 28.07% examples, 9839 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 33.52% examples, 9972 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 41.89% examples, 11021 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 49.99% examples, 10855 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 55.30% examples, 11256 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 62.39% examples, 11638 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 66.89% examples, 11467 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 73.44% examples, 11835 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 80.11% examples, 12429 words/s, in_qsize 10, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 84.43% examples, 11102 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 86.57% examples, 10613 words/s, in_qsize 7, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 94.54% examples, 11158 words/s, in_qsize 3, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 100.00% examples, 11236 words/s, in_qsize 0, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 11 : training on 425288 raw words (406827 effective words) took 36.2s, 11236 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 2.51% examples, 2277 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 6.92% examples, 4621 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 9.48% examples, 4568 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 16.28% examples, 6994 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 22.99% examples, 8737 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 28.07% examples, 8995 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 41.89% examples, 11650 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 47.19% examples, 11527 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 49.99% examples, 10974 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 55.30% examples, 11377 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 60.17% examples, 11137 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 66.89% examples, 11538 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 73.44% examples, 12024 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 75.76% examples, 11881 words/s, in_qsize 12, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 80.10% examples, 12139 words/s, in_qsize 10, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 84.43% examples, 11247 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 86.57% examples, 10874 words/s, in_qsize 7, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 92.71% examples, 11307 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 94.54% examples, 11082 words/s, in_qsize 3, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 98.54% examples, 11138 words/s, in_qsize 1, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 12 : training on 425288 raw words (406721 effective words) took 36.5s, 11152 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 2.51% examples, 2273 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 6.92% examples, 4371 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 9.48% examples, 4604 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 16.28% examples, 6766 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 22.69% examples, 8744 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 28.07% examples, 9321 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 33.52% examples, 9898 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 41.89% examples, 11024 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 49.99% examples, 10801 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 57.64% examples, 11476 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 64.68% examples, 11711 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 66.89% examples, 11234 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 75.76% examples, 11825 words/s, in_qsize 12, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 84.43% examples, 11210 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 86.57% examples, 10596 words/s, in_qsize 7, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 94.54% examples, 11184 words/s, in_qsize 3, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 98.54% examples, 11343 words/s, in_qsize 1, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 100.00% examples, 11163 words/s, in_qsize 0, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 13 : training on 425288 raw words (406776 effective words) took 36.4s, 11162 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 2.51% examples, 2112 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 6.92% examples, 4395 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 9.48% examples, 4561 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 16.28% examples, 6809 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 25.27% examples, 9502 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 28.07% examples, 9122 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 36.54% examples, 10483 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 44.46% examples, 11378 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 49.99% examples, 10786 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 55.30% examples, 11084 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 62.39% examples, 11667 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 66.89% examples, 11303 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 73.44% examples, 11633 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 80.11% examples, 12132 words/s, in_qsize 10, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 84.43% examples, 11391 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 86.31% examples, 10677 words/s, in_qsize 7, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 92.71% examples, 11105 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 94.54% examples, 10994 words/s, in_qsize 3, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 98.54% examples, 11206 words/s, in_qsize 1, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 14 : training on 425288 raw words (406753 effective words) took 36.4s, 11160 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 2.51% examples, 2221 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 6.92% examples, 4158 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 9.48% examples, 4612 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 16.28% examples, 6855 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 22.69% examples, 8651 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 28.07% examples, 9152 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 34.15% examples, 9829 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 44.62% examples, 11358 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 49.99% examples, 10558 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 57.64% examples, 11355 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 62.39% examples, 11722 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 66.89% examples, 11254 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 71.29% examples, 11522 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 77.85% examples, 11887 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 84.43% examples, 11229 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 86.57% examples, 10514 words/s, in_qsize 7, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 94.54% examples, 10813 words/s, in_qsize 3, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 98.54% examples, 11032 words/s, in_qsize 1, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 15 : training on 425288 raw words (406917 effective words) took 36.9s, 11032 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 2.51% examples, 2175 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 6.92% examples, 4358 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 9.48% examples, 4571 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 16.28% examples, 6894 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 20.62% examples, 7953 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 28.07% examples, 9132 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 33.73% examples, 9814 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 41.89% examples, 10945 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 49.99% examples, 10746 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 57.64% examples, 11027 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 64.68% examples, 11552 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 66.89% examples, 11264 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 73.44% examples, 11865 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 75.55% examples, 11461 words/s, in_qsize 12, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 84.43% examples, 10989 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 86.57% examples, 10478 words/s, in_qsize 7, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# ...
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 7.65% examples, 5172 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 9.65% examples, 4488 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 17.57% examples, 6993 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 24.63% examples, 8255 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 30.91% examples, 9027 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 39.49% examples, 9903 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 45.00% examples, 10308 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 49.98% examples, 10028 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 55.16% examples, 10275 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 60.01% examples, 10624 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 64.86% examples, 10896 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 69.66% examples, 10797 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 77.14% examples, 11152 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 79.30% examples, 10998 words/s, in_qsize 10, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 83.99% examples, 10942 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 88.19% examples, 10366 words/s, in_qsize 6, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 92.60% examples, 10620 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 94.89% examples, 10341 words/s, in_qsize 3, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 96.06% examples, 9830 words/s, in_qsize 2, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 26 : training on 404784 raw words (387362 effective words) took 38.1s, 10173 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 2.85% examples, 2321 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 7.65% examples, 5078 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 9.65% examples, 4426 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 22.72% examples, 8934 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 24.63% examples, 8194 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 33.91% examples, 9380 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 39.49% examples, 9806 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 45.00% examples, 10245 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 47.10% examples, 10149 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 49.98% examples, 9987 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 52.68% examples, 9892 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 57.49% examples, 9936 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 67.25% examples, 11198 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 69.54% examples, 10540 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 77.14% examples, 11000 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 79.35% examples, 10865 words/s, in_qsize 10, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 83.99% examples, 10931 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 88.19% examples, 10273 words/s, in_qsize 6, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 94.89% examples, 10391 words/s, in_qsize 3, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 96.06% examples, 9675 words/s, in_qsize 2, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 98.03% examples, 9643 words/s, in_qsize 1, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 27 : training on 404784 raw words (387382 effective words) took 39.2s, 9874 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 2.85% examples, 2299 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 7.65% examples, 5139 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 9.65% examples, 4164 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 24.63% examples, 8359 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 30.91% examples, 9101 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 36.75% examples, 9624 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 42.02% examples, 10112 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 47.10% examples, 10319 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 49.98% examples, 9828 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 57.49% examples, 10096 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 67.25% examples, 11118 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 69.68% examples, 10553 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 77.14% examples, 11090 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 79.35% examples, 10906 words/s, in_qsize 10, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 83.99% examples, 10974 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 86.18% examples, 10870 words/s, in_qsize 7, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 88.19% examples, 10226 words/s, in_qsize 6, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 94.89% examples, 10260 words/s, in_qsize 3, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 96.85% examples, 9732 words/s, in_qsize 2, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 28 : training on 404784 raw words (387367 effective words) took 39.0s, 9927 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 2.50% examples, 2182 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 7.65% examples, 4876 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 9.65% examples, 4408 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 19.91% examples, 7712 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 24.63% examples, 8042 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 33.91% examples, 9180 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 39.29% examples, 9817 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 45.00% examples, 10141 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 49.98% examples, 9798 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 55.16% examples, 10250 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 57.69% examples, 10198 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 62.40% examples, 10347 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 69.68% examples, 10580 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 77.14% examples, 10869 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 81.51% examples, 11079 words/s, in_qsize 9, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 83.99% examples, 10725 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 88.19% examples, 10275 words/s, in_qsize 6, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 92.60% examples, 10446 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 94.89% examples, 10130 words/s, in_qsize 3, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 96.85% examples, 9612 words/s, in_qsize 2, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 29 : training on 404784 raw words (387107 effective words) took 39.4s, 9819 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 2.50% examples, 2194 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 7.65% examples, 5187 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 9.65% examples, 4329 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 20.15% examples, 7653 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 24.63% examples, 8019 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 33.91% examples, 9257 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 39.49% examples, 9591 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 45.00% examples, 10125 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 47.10% examples, 9621 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 52.68% examples, 9691 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 57.49% examples, 10113 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 62.40% examples, 10454 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 69.54% examples, 10359 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 77.14% examples, 10943 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 81.51% examples, 10879 words/s, in_qsize 9, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 83.99% examples, 10690 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 86.18% examples, 10550 words/s, in_qsize 7, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 88.19% examples, 9870 words/s, in_qsize 6, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 94.89% examples, 10036 words/s, in_qsize 3, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 96.85% examples, 9689 words/s, in_qsize 2, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 30 : training on 404784 raw words (387381 effective words) took 38.6s, 10045 effective words/s
# INFO:gensim.models.base_any2vec:training on a 12143520 raw words (11618001 effective words) took 1124.7s, 10330 effective words/s
# INFO:gensim.utils:saving Word2Vec object under model_5, separately None
# INFO:gensim.utils:not storing attribute vectors_norm
# INFO:gensim.utils:not storing attribute cum_table
# INFO:gensim.utils:saved model_5
# INFO:gensim.models.keyedvectors:precomputing L2-norms of word weight vectors
# Score @10: 0.09106480159862974
# Score @15: 0.11390236939765915
# Score @20: 0.13502711961176134
# Mean score @10= 0.09569456199876444
# Mean score @15= 0.11905416539356233
# Mean score @20= 0.13720926865083055

# %% [markdown]
# ## References
# \[1\] Barkan, O., & Koenigstein, N. (2016). [ITEM2VEC: Neural item embedding for collaborative filtering](https://arxiv.org/abs/1603.04259). 2016 IEEE 26th International Workshop on Machine Learning for Signal Processing (MLSP), 1-6.
#
# \[2\] Hugo Caselles-Dupre, Florian Lesaint, and Jimena Royo-Letelier. [Word2vec applied to recommendation: Hyperparameters matter](https://arxiv.org/abs/1804.04212). CoRR, abs/1804.04212, 2018.
#
# \[3\] Makbule Gulcin Ozsoy. 2016. [From word embeddings to item recommendation](https://arxiv.org/abs/1601.01356). arXiv preprint arXiv:1601.01356 (2016).
#
# \[4\] http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
#
# \[5\] Tomas Mikolov, Ilya Sutskever, Kai Chen, Greg Corrado, and Jeffrey Dean. 2013b. [Distributed representations of words and phrases and their compositionality](https://arxiv.org/abs/1310.4546). In NIPS, pages 3111–3119.
#
# \[6\] [Online Retail Data](https://archive.ics.uci.edu/ml/datasets/Online+Retail)
